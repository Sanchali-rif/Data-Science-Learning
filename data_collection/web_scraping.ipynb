# %% [markdown]
# ## Fetching the data

# %%
import requests
URL="http://scrapethissite.com/pages/simple/" # a webscraping site
res=requests.get(URL)
print(res.status_code) # returns HTTP status
# Out:
# 200

# %%
print(res.headers) # metadata like content type , server info etc
# Out:
# {'Date': 'Wed, 19 Aug 2026 15:35:57 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Nel': '{"report_to":"heroku-nel","response_headers":["Via"],"max_age":3600,"success_fraction":0.01,"failure_fraction":0.1}', 'Report-To': '{"group":"heroku-nel","endpoints":[{"url":"https://nel.heroku.com/reports?s=X2DA77I2p5rW4pK0Aq5YWMpUjgZ0ufga5ZYL6Y21CFw%3D\\u0026sid=67ff5de4-ad2b-4112-9289-cf96be89efed\\u0026ts=1787153756"}],"max_age":3600}', 'Reporting-Endpoints': 'heroku-nel="https://nel.heroku.com/reports?s=X2DA77I2p5rW4pK0Aq5YWMpUjgZ0ufga5ZYL6Y21CFw%3D&sid=67ff5de4-ad2b-4112-9289-cf96be89efed&ts=1787153756"', 'Server': 'cloudflare', 'Via': '1.1 heroku-router', 'cf-cache-status': 'DYNAMIC', 'Content-Encoding': 'zstd', 'CF-RAY': 'a2da3b2138a4f87e-SIN', 'alt-svc': 'h3=":443"; ma=86400'}

# %%
if res.status_code==200: # always check status code
    print(res.text) # returns the html content of the web page

# %% [markdown]
# ## Downloading & storing to file

# %%
with open("scraped_data/data1.html","w", encoding="utf-8") as f:
    f.write(res.text) # write the file content in the file
